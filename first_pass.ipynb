# %%
# %load_ext autoreload
import pipeline as p
import loops as l
import numpy as np
import pandas as pd

# %%
obj = p.process()
df = obj.df

# %%
df.loc[:,'top_10_eviction_rate'] = np.where(df['eviction-rate'] >= df['eviction-rate'].quantile(.9), 1,0)

# %%
x_train, y_train, x_test, y_test = p.get_train_test_splits(df)

# %%
for df in [x_train, x_test]:
    p.fill_continuous_null(df, p.FEATURES)

# %%
for col in p.FEATURES:
    x_train = p.discretize(x_train, col, 50)

# %%
for col in p.FEATURES:
    x_test = p.discretize(x_test, col, 50)

# %%
x_train['label'] = 'train'
x_test['label'] = 'score'
concat_df = pd.concat([x_train , x_test])
features_df = pd.get_dummies(concat_df, columns=p.FEATURES)

# %%
x_train = features_df[features_df['label'] == 'train']
x_test = features_df[features_df['label'] == 'score']
                             
x_train = x_train.drop('label', axis=1)
x_test = x_test.drop('label', axis=1)

# %%
clfs, grid = l.define_clfs_params('test')

# %%
models_to_run = ['RF','DT','GB','LR','KNN']

# %%
output =l.clf_loop(models_to_run, clfs, grid, x_train, x_test, y_train, y_test)
# Out:
# RF
# DT
# GB
# LR
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# KNN

# %%
output.sort_values('auc-roc', ascending=False)
# Out:
#    model_type                                                clf  \
# 22         LR  LogisticRegression(C=0.1, class_weight=None, d...
# 24         LR  LogisticRegression(C=0.1, class_weight=None, d...
# 5          RF  (DecisionTreeClassifier(class_weight=None, cri...
# 18         GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 7          DT  DecisionTreeClassifier(class_weight=None, crit...
# 13         DT  DecisionTreeClassifier(class_weight=None, crit...
# 12         DT  DecisionTreeClassifier(class_weight=None, crit...
# 14         DT  DecisionTreeClassifier(class_weight=None, crit...
# 8          DT  DecisionTreeClassifier(class_weight=None, crit...
# 19         GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 20         GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 23         LR  LogisticRegression(C=0.1, class_weight=None, d...
# 6          DT  DecisionTreeClassifier(class_weight=None, crit...
# 21         LR  LogisticRegression(C=0.1, class_weight=None, d...
# 4          RF  (DecisionTreeClassifier(class_weight=None, cri...
# 2          RF  (DecisionTreeClassifier(class_weight=None, cri...
# 27        KNN  KNeighborsClassifier(algorithm='auto', leaf_si...
# 26        KNN  KNeighborsClassifier(algorithm='auto', leaf_si...
# 11         DT  DecisionTreeClassifier(class_weight=None, crit...
# 16         DT  DecisionTreeClassifier(class_weight=None, crit...
# 17         DT  DecisionTreeClassifier(class_weight=None, crit...
# 10         DT  DecisionTreeClassifier(class_weight=None, crit...
# 9          DT  DecisionTreeClassifier(class_weight=None, crit...
# 15         DT  DecisionTreeClassifier(class_weight=None, crit...
# 25        KNN  KNeighborsClassifier(algorithm='auto', leaf_si...
# 3          RF  (DecisionTreeClassifier(class_weight=None, cri...
# 1          RF  (DecisionTreeClassifier(class_weight=None, cri...
# 0          RF  (DecisionTreeClassifier(class_weight=None, cri...
#
#                                            parameters  \
# 22                       {'C': 0.01, 'penalty': 'l2'}
# 24                        {'C': 0.1, 'penalty': 'l2'}
# 5   {'max_depth': 5, 'max_features': 'sqrt', 'min_...
# 18  {'learning_rate': 0.1, 'max_depth': 1, 'n_esti...
# 7   {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 13  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 12  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 14  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 8   {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 19  {'learning_rate': 0.1, 'max_depth': 1, 'n_esti...
# 20  {'learning_rate': 0.1, 'max_depth': 1, 'n_esti...
# 23                        {'C': 0.1, 'penalty': 'l1'}
# 6   {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 21                       {'C': 0.01, 'penalty': 'l1'}
# 4   {'max_depth': 5, 'max_features': 'sqrt', 'min_...
# 2   {'max_depth': 1, 'max_features': 'sqrt', 'min_...
# 27  {'algorithm': 'auto', 'n_neighbors': 10, 'weig...
# 26  {'algorithm': 'auto', 'n_neighbors': 5, 'weigh...
# 11  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 16  {'criterion': 'entropy', 'max_depth': 10, 'min...
# 17  {'criterion': 'entropy', 'max_depth': 10, 'min...
# 10  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 9   {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 15  {'criterion': 'entropy', 'max_depth': 10, 'min...
# 25  {'algorithm': 'auto', 'n_neighbors': 2, 'weigh...
# 3   {'max_depth': 5, 'max_features': 'sqrt', 'min_...
# 1   {'max_depth': 1, 'max_features': 'sqrt', 'min_...
# 0   {'max_depth': 1, 'max_features': 'sqrt', 'min_...
#
#                                            baseline   auc-roc   f1_at_5  \
# 22  top_10_eviction_rate    0.082285
# dtype: float64  0.955736  0.571429
# 24  top_10_eviction_rate    0.082285
# dtype: float64  0.951716  0.595238
# 5   top_10_eviction_rate    0.082285
# dtype: float64  0.931211  0.468254
# 18  top_10_eviction_rate    0.082285
# dtype: float64  0.929058  0.563492
# 7   top_10_eviction_rate    0.082285
# dtype: float64  0.895083  0.396825
# 13  top_10_eviction_rate    0.082285
# dtype: float64  0.895083  0.396825
# 12  top_10_eviction_rate    0.082285
# dtype: float64  0.895061  0.396825
# 14  top_10_eviction_rate    0.082285
# dtype: float64  0.894757  0.396825
# 8   top_10_eviction_rate    0.082285
# dtype: float64  0.894757  0.396825
# 19  top_10_eviction_rate    0.082285
# dtype: float64  0.894530  0.285714
# 20  top_10_eviction_rate    0.082285
# dtype: float64  0.893037  0.269841
# 23  top_10_eviction_rate    0.082285
# dtype: float64  0.889461  0.365079
# 6   top_10_eviction_rate    0.082285
# dtype: float64  0.889241  0.380952
# 21  top_10_eviction_rate    0.082285
# dtype: float64  0.887829  0.071429
# 4   top_10_eviction_rate    0.082285
# dtype: float64  0.806618  0.444444
# 2   top_10_eviction_rate    0.082285
# dtype: float64  0.770786  0.341270
# 27  top_10_eviction_rate    0.082285
# dtype: float64  0.758555  0.412698
# 26  top_10_eviction_rate    0.082285
# dtype: float64  0.697652  0.365079
# 11  top_10_eviction_rate    0.082285
# dtype: float64  0.656573  0.396825
# 16  top_10_eviction_rate    0.082285
# dtype: float64  0.650667  0.380952
# 17  top_10_eviction_rate    0.082285
# dtype: float64  0.650324  0.380952
# 10  top_10_eviction_rate    0.082285
# dtype: float64  0.650140  0.380952
# 9   top_10_eviction_rate    0.082285
# dtype: float64  0.647255  0.373016
# 15  top_10_eviction_rate    0.082285
# dtype: float64  0.644551  0.365079
# 25  top_10_eviction_rate    0.082285
# dtype: float64  0.624806  0.325397
# 3   top_10_eviction_rate    0.082285
# dtype: float64  0.616861  0.166667
# 1   top_10_eviction_rate    0.082285
# dtype: float64  0.568831  0.174603
# 0   top_10_eviction_rate    0.082285
# dtype: float64  0.506369  0.015873
#
#     f1_at_10    a_at_5   a_at_10    p_at_1  ...   p_at_20   p_at_30   p_at_50  \
# 22  0.691643  0.943396  0.943920  1.000000  ...  0.377953  0.262238  0.162474
# 24  0.703170  0.946541  0.946017  1.000000  ...  0.377953  0.262238  0.160377
# 5   0.489914  0.929769  0.907233  0.368421  ...  0.367454  0.244755  0.163522
# 18  0.599424  0.942348  0.927149  1.000000  ...  0.372703  0.251748  0.164570
# 7   0.466859  0.920335  0.903040  0.894737  ...  0.346457  0.230769  0.164570
# 13  0.466859  0.920335  0.903040  0.894737  ...  0.346457  0.230769  0.164570
# 12  0.466859  0.920335  0.903040  0.894737  ...  0.346457  0.230769  0.164570
# 14  0.466859  0.920335  0.903040  0.842105  ...  0.346457  0.230769  0.164570
# 8   0.466859  0.920335  0.903040  0.842105  ...  0.346457  0.230769  0.164570
# 19  0.438040  0.905660  0.897799  0.684211  ...  0.349081  0.232517  0.164570
# 20  0.443804  0.903564  0.898847  1.000000  ...  0.346457  0.230769  0.164570
# 23  0.501441  0.916143  0.909329  1.000000  ...  0.346457  0.230769  0.159329
# 6   0.478386  0.918239  0.905136  1.000000  ...  0.341207  0.227273  0.164570
# 21  0.438040  0.877358  0.897799  0.052632  ...  0.346457  0.230769  0.164570
# 4   0.432277  0.926625  0.896751  0.789474  ...  0.241470  0.160839  0.162474
# 2   0.270893  0.912998  0.867400  0.421053  ...  0.123360  0.085664  0.162474
# 27  0.495677  0.922432  0.908281  0.842105  ...  0.225722  0.150350  0.164570
# 26  0.380403  0.916143  0.887317  0.684211  ...  0.173228  0.115385  0.164570
# 11  0.288184  0.920335  0.870545  0.842105  ...  0.131234  0.087413  0.164570
# 16  0.276657  0.918239  0.868449  0.894737  ...  0.125984  0.083916  0.164570
# 17  0.276657  0.918239  0.868449  0.894737  ...  0.125984  0.083916  0.164570
# 10  0.276657  0.918239  0.868449  0.842105  ...  0.125984  0.083916  0.164570
# 9   0.270893  0.917191  0.867400  0.894737  ...  0.123360  0.082168  0.164570
# 15  0.265130  0.916143  0.866352  0.894737  ...  0.120735  0.080420  0.164570
# 25  0.236311  0.910901  0.861111  0.631579  ...  0.107612  0.080420  0.164570
# 3   0.270893  0.889937  0.867400  0.421053  ...  0.128609  0.085664  0.164570
# 1   0.126801  0.890985  0.841195  0.789474  ...  0.057743  0.071678  0.164570
# 0   0.011527  0.870021  0.820231  0.105263  ...  0.005249  0.066434  0.164570
#
#       r_at_1    r_at_2    r_at_5   r_at_10   r_at_20   r_at_30   r_at_50
# 22  0.121019  0.235669  0.458599  0.764331  0.917197  0.955414  0.987261
# 24  0.121019  0.235669  0.477707  0.777070  0.917197  0.955414  0.974522
# 5   0.044586  0.146497  0.375796  0.541401  0.891720  0.891720  0.993631
# 18  0.121019  0.178344  0.452229  0.662420  0.904459  0.917197  1.000000
# 7   0.108280  0.184713  0.318471  0.515924  0.840764  0.840764  1.000000
# 13  0.108280  0.184713  0.318471  0.515924  0.840764  0.840764  1.000000
# 12  0.108280  0.184713  0.318471  0.515924  0.840764  0.840764  1.000000
# 14  0.101911  0.184713  0.318471  0.515924  0.840764  0.840764  1.000000
# 8   0.101911  0.184713  0.318471  0.515924  0.840764  0.840764  1.000000
# 19  0.082803  0.178344  0.229299  0.484076  0.847134  0.847134  1.000000
# 20  0.121019  0.197452  0.216561  0.490446  0.840764  0.840764  1.000000
# 23  0.121019  0.210191  0.292994  0.554140  0.840764  0.840764  0.968153
# 6   0.121019  0.191083  0.305732  0.528662  0.828025  0.828025  1.000000
# 21  0.006369  0.038217  0.057325  0.484076  0.840764  0.840764  1.000000
# 4   0.095541  0.203822  0.356688  0.477707  0.585987  0.585987  0.987261
# 2   0.050955  0.114650  0.273885  0.299363  0.299363  0.312102  0.987261
# 27  0.101911  0.216561  0.331210  0.547771  0.547771  0.547771  1.000000
# 26  0.082803  0.184713  0.292994  0.420382  0.420382  0.420382  1.000000
# 11  0.101911  0.216561  0.318471  0.318471  0.318471  0.318471  1.000000
# 16  0.108280  0.210191  0.305732  0.305732  0.305732  0.305732  1.000000
# 17  0.108280  0.210191  0.305732  0.305732  0.305732  0.305732  1.000000
# 10  0.101911  0.203822  0.305732  0.305732  0.305732  0.305732  1.000000
# 9   0.108280  0.191083  0.299363  0.299363  0.299363  0.299363  1.000000
# 15  0.108280  0.197452  0.292994  0.292994  0.292994  0.292994  1.000000
# 25  0.076433  0.108280  0.261146  0.261146  0.261146  0.292994  1.000000
# 3   0.050955  0.101911  0.133758  0.299363  0.312102  0.312102  1.000000
# 1   0.095541  0.140127  0.140127  0.140127  0.140127  0.261146  1.000000
# 0   0.012739  0.012739  0.012739  0.012739  0.012739  0.242038  1.000000
#
# [28 rows x 23 columns]

# %%
output.loc[22,:]
# Out:
# model_type                                                   LR
# clf           LogisticRegression(C=0.1, class_weight=None, d...
# parameters                         {'C': 0.01, 'penalty': 'l2'}
# baseline        top_10_eviction_rate    0.082285
# dtype: float64
# auc-roc                                                0.955736
# f1_at_5                                                0.571429
# f1_at_10                                               0.691643
# a_at_5                                                 0.943396
# a_at_10                                                 0.94392
# p_at_1                                                        1
# p_at_2                                                 0.973684
# p_at_5                                                 0.757895
# p_at_10                                                0.631579
# p_at_20                                                0.377953
# p_at_30                                                0.262238
# p_at_50                                                0.162474
# r_at_1                                                 0.121019
# r_at_2                                                 0.235669
# r_at_5                                                 0.458599
# r_at_10                                                0.764331
# r_at_20                                                0.917197
# r_at_30                                                0.955414
# r_at_50                                                0.987261
# Name: 22, dtype: object

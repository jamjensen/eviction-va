# %%
# %load_ext autoreload
import pipeline as p
import loops as l
import numpy as np
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load data

# %%
df = p.load_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-5b727d05bbee> in <module>
# ----> 1 df = p.load_data()
#
# AttributeError: module 'pipeline' has no attribute 'load_data'

# %% [markdown]
# # Create binary outcome label

# %%
df.loc[:,'top_10_eviction_rate'] = np.where(df['eviction-rate'] >= df['eviction-rate'].quantile(.9), 1,0)

# %% [markdown]
# # Generate train and test sets

# %%
x_train, y_train, x_test, y_test = p.get_train_test_splits(df)

# %% [markdown]
# # Clean data

# %%
for df in [x_train, x_test]:
    p.fill_continuous_null(df, p.FEATURES)

# %% [markdown]
# # Create features

# %%
for col in p.FEATURES:
    x_train = p.discretize(x_train, col, 50)

# %%
for col in p.FEATURES:
    x_test = p.discretize(x_test, col, 50)

# %%
x_train['label'] = 'train'
x_test['label'] = 'score'
concat_df = pd.concat([x_train , x_test])
features_df = pd.get_dummies(concat_df, columns=p.FEATURES)

# %%
x_train = features_df[features_df['label'] == 'train']
x_test = features_df[features_df['label'] == 'score']
                             
x_train = x_train.drop('label', axis=1)
x_test = x_test.drop('label', axis=1)

# %% [markdown]
# # Define models and parameters

# %%
clfs, grid = l.define_clfs_params('test')

# %%
models_to_run = ['RF','DT','GB','LR','KNN']

# %% [markdown]
# # Loop for all models

# %%
output =l.clf_loop(models_to_run, clfs, grid, x_train, x_test, y_train, y_test)
# Out:
# RF
# DT
# GB
# LR
# KNN

# %% [markdown]
# # Sort according to best model

# %%
output.sort_values('auc-roc', ascending=False)
# Out:
#    model_type                                                clf  \
# 22         LR  LogisticRegression(C=0.1, class_weight=None, d...
# 24         LR  LogisticRegression(C=0.1, class_weight=None, d...
# 5          RF  (DecisionTreeClassifier(class_weight=None, cri...
# 18         GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 4          RF  (DecisionTreeClassifier(class_weight=None, cri...
# 19         GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 12         DT  DecisionTreeClassifier(class_weight=None, crit...
# 7          DT  DecisionTreeClassifier(class_weight=None, crit...
# 13         DT  DecisionTreeClassifier(class_weight=None, crit...
# 14         DT  DecisionTreeClassifier(class_weight=None, crit...
# 8          DT  DecisionTreeClassifier(class_weight=None, crit...
# 20         GB  ([DecisionTreeRegressor(criterion='friedman_ms...
# 23         LR  LogisticRegression(C=0.1, class_weight=None, d...
# 6          DT  DecisionTreeClassifier(class_weight=None, crit...
# 1          RF  (DecisionTreeClassifier(class_weight=None, cri...
# 2          RF  (DecisionTreeClassifier(class_weight=None, cri...
# 21         LR  LogisticRegression(C=0.1, class_weight=None, d...
# 27        KNN  KNeighborsClassifier(algorithm='auto', leaf_si...
# 26        KNN  KNeighborsClassifier(algorithm='auto', leaf_si...
# 11         DT  DecisionTreeClassifier(class_weight=None, crit...
# 17         DT  DecisionTreeClassifier(class_weight=None, crit...
# 16         DT  DecisionTreeClassifier(class_weight=None, crit...
# 10         DT  DecisionTreeClassifier(class_weight=None, crit...
# 9          DT  DecisionTreeClassifier(class_weight=None, crit...
# 15         DT  DecisionTreeClassifier(class_weight=None, crit...
# 25        KNN  KNeighborsClassifier(algorithm='auto', leaf_si...
# 3          RF  (DecisionTreeClassifier(class_weight=None, cri...
# 0          RF  (DecisionTreeClassifier(class_weight=None, cri...
#
#                                            parameters  \
# 22                       {'C': 0.01, 'penalty': 'l2'}
# 24                        {'C': 0.1, 'penalty': 'l2'}
# 5   {'n_estimators': 10, 'max_depth': 5, 'min_samp...
# 18  {'learning_rate': 0.1, 'n_estimators': 100, 'm...
# 4   {'n_estimators': 5, 'max_depth': 5, 'min_sampl...
# 19  {'learning_rate': 0.1, 'n_estimators': 50, 'ma...
# 12  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 7   {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 13  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 14  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 8   {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 20  {'learning_rate': 0.1, 'n_estimators': 30, 'ma...
# 23                        {'C': 0.1, 'penalty': 'l1'}
# 6   {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 1   {'n_estimators': 5, 'max_depth': 1, 'min_sampl...
# 2   {'n_estimators': 10, 'max_depth': 1, 'min_samp...
# 21                       {'C': 0.01, 'penalty': 'l1'}
# 27  {'weights': 'uniform', 'algorithm': 'auto', 'n...
# 26  {'weights': 'uniform', 'algorithm': 'auto', 'n...
# 11  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 17  {'criterion': 'entropy', 'max_depth': 10, 'min...
# 16  {'criterion': 'entropy', 'max_depth': 10, 'min...
# 10  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 9   {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 15  {'criterion': 'entropy', 'max_depth': 10, 'min...
# 25  {'weights': 'uniform', 'algorithm': 'auto', 'n...
# 3   {'n_estimators': 1, 'max_depth': 5, 'min_sampl...
# 0   {'n_estimators': 1, 'max_depth': 1, 'min_sampl...
#
#                                            baseline   auc-roc   f1_at_5  \
# 22  top_10_eviction_rate    0.082285
# dtype: float64  0.955736  0.571429
# 24  top_10_eviction_rate    0.082285
# dtype: float64  0.951716  0.595238
# 5   top_10_eviction_rate    0.082285
# dtype: float64  0.943188  0.436508
# 18  top_10_eviction_rate    0.082285
# dtype: float64  0.923958  0.507937
# 4   top_10_eviction_rate    0.082285
# dtype: float64  0.913825  0.341270
# 19  top_10_eviction_rate    0.082285
# dtype: float64  0.899117  0.420635
# 12  top_10_eviction_rate    0.082285
# dtype: float64  0.895083  0.396825
# 7   top_10_eviction_rate    0.082285
# dtype: float64  0.895083  0.396825
# 13  top_10_eviction_rate    0.082285
# dtype: float64  0.894757  0.396825
# 14  top_10_eviction_rate    0.082285
# dtype: float64  0.894733  0.396825
# 8   top_10_eviction_rate    0.082285
# dtype: float64  0.894733  0.396825
# 20  top_10_eviction_rate    0.082285
# dtype: float64  0.893489  0.119048
# 23  top_10_eviction_rate    0.082285
# dtype: float64  0.889461  0.365079
# 6   top_10_eviction_rate    0.082285
# dtype: float64  0.889241  0.380952
# 1   top_10_eviction_rate    0.082285
# dtype: float64  0.889097  0.293651
# 2   top_10_eviction_rate    0.082285
# dtype: float64  0.889086  0.285714
# 21  top_10_eviction_rate    0.082285
# dtype: float64  0.887829  0.071429
# 27  top_10_eviction_rate    0.082285
# dtype: float64  0.758555  0.412698
# 26  top_10_eviction_rate    0.082285
# dtype: float64  0.697652  0.365079
# 11  top_10_eviction_rate    0.082285
# dtype: float64  0.656167  0.396825
# 17  top_10_eviction_rate    0.082285
# dtype: float64  0.650324  0.380952
# 16  top_10_eviction_rate    0.082285
# dtype: float64  0.650302  0.380952
# 10  top_10_eviction_rate    0.082285
# dtype: float64  0.649772  0.380952
# 9   top_10_eviction_rate    0.082285
# dtype: float64  0.647281  0.373016
# 15  top_10_eviction_rate    0.082285
# dtype: float64  0.638525  0.349206
# 25  top_10_eviction_rate    0.082285
# dtype: float64  0.624806  0.325397
# 3   top_10_eviction_rate    0.082285
# dtype: float64  0.518819  0.047619
# 0   top_10_eviction_rate    0.082285
# dtype: float64  0.514210  0.039683
#
#     f1_at_10    a_at_5   a_at_10    p_at_1    ...      p_at_20   p_at_30  \
# 22  0.691643  0.943396  0.943920  1.000000    ...     0.377953  0.262238
# 24  0.703170  0.946541  0.946017  1.000000    ...     0.377953  0.262238
# 5   0.582133  0.925577  0.924004  0.894737    ...     0.370079  0.267483
# 18  0.605187  0.935010  0.928197  0.894737    ...     0.372703  0.248252
# 4   0.380403  0.912998  0.887317  0.684211    ...     0.354331  0.236014
# 19  0.466859  0.923480  0.903040  0.789474    ...     0.351706  0.234266
# 12  0.466859  0.920335  0.903040  0.894737    ...     0.346457  0.230769
# 7   0.466859  0.920335  0.903040  0.894737    ...     0.346457  0.230769
# 13  0.466859  0.920335  0.903040  0.842105    ...     0.346457  0.230769
# 14  0.466859  0.920335  0.903040  0.842105    ...     0.346457  0.230769
# 8   0.466859  0.920335  0.903040  0.842105    ...     0.346457  0.230769
# 20  0.438040  0.883648  0.897799  0.736842    ...     0.349081  0.232517
# 23  0.501441  0.916143  0.909329  1.000000    ...     0.346457  0.230769
# 6   0.478386  0.918239  0.905136  1.000000    ...     0.341207  0.227273
# 1   0.409222  0.906709  0.892558  0.631579    ...     0.354331  0.236014
# 2   0.420749  0.905660  0.894654  0.578947    ...     0.351706  0.234266
# 21  0.438040  0.877358  0.897799  0.052632    ...     0.346457  0.230769
# 27  0.495677  0.922432  0.908281  0.842105    ...     0.225722  0.150350
# 26  0.380403  0.916143  0.887317  0.684211    ...     0.173228  0.115385
# 11  0.288184  0.920335  0.870545  0.789474    ...     0.131234  0.087413
# 17  0.276657  0.918239  0.868449  0.894737    ...     0.125984  0.083916
# 16  0.276657  0.918239  0.868449  0.894737    ...     0.125984  0.083916
# 10  0.276657  0.918239  0.868449  0.789474    ...     0.125984  0.083916
# 9   0.270893  0.917191  0.867400  0.894737    ...     0.123360  0.082168
# 15  0.253602  0.914046  0.864256  0.947368    ...     0.115486  0.076923
# 25  0.236311  0.910901  0.861111  0.631579    ...     0.107612  0.080420
# 3   0.034582  0.874214  0.824423  0.315789    ...     0.015748  0.068182
# 0   0.028818  0.873166  0.823375  0.263158    ...     0.013123  0.069930
#
#      p_at_50    r_at_1    r_at_2    r_at_5   r_at_10   r_at_20   r_at_30  \
# 22  0.162474  0.121019  0.235669  0.458599  0.764331  0.917197  0.955414
# 24  0.160377  0.121019  0.235669  0.477707  0.777070  0.917197  0.955414
# 5   0.163522  0.108280  0.165605  0.350318  0.643312  0.898089  0.974522
# 18  0.164570  0.108280  0.203822  0.407643  0.668790  0.904459  0.904459
# 4   0.160377  0.082803  0.171975  0.273885  0.420382  0.859873  0.859873
# 19  0.164570  0.095541  0.152866  0.337580  0.515924  0.853503  0.853503
# 12  0.164570  0.108280  0.184713  0.318471  0.515924  0.840764  0.840764
# 7   0.164570  0.108280  0.184713  0.318471  0.515924  0.840764  0.840764
# 13  0.164570  0.101911  0.184713  0.318471  0.515924  0.840764  0.840764
# 14  0.164570  0.101911  0.178344  0.318471  0.515924  0.840764  0.840764
# 8   0.164570  0.101911  0.178344  0.318471  0.515924  0.840764  0.840764
# 20  0.164570  0.089172  0.089172  0.095541  0.484076  0.847134  0.847134
# 23  0.159329  0.121019  0.210191  0.292994  0.554140  0.840764  0.840764
# 6   0.164570  0.121019  0.191083  0.305732  0.528662  0.828025  0.828025
# 1   0.164570  0.076433  0.121019  0.235669  0.452229  0.859873  0.859873
# 2   0.162474  0.070064  0.140127  0.229299  0.464968  0.853503  0.853503
# 21  0.164570  0.006369  0.038217  0.057325  0.484076  0.840764  0.840764
# 27  0.164570  0.101911  0.216561  0.331210  0.547771  0.547771  0.547771
# 26  0.164570  0.082803  0.184713  0.292994  0.420382  0.420382  0.420382
# 11  0.164570  0.095541  0.210191  0.318471  0.318471  0.318471  0.318471
# 17  0.164570  0.108280  0.210191  0.305732  0.305732  0.305732  0.305732
# 16  0.164570  0.108280  0.210191  0.305732  0.305732  0.305732  0.305732
# 10  0.164570  0.095541  0.203822  0.305732  0.305732  0.305732  0.305732
# 9   0.164570  0.108280  0.191083  0.299363  0.299363  0.299363  0.299363
# 15  0.164570  0.114650  0.203822  0.280255  0.280255  0.280255  0.280255
# 25  0.164570  0.076433  0.108280  0.261146  0.261146  0.261146  0.292994
# 3   0.164570  0.038217  0.038217  0.038217  0.038217  0.038217  0.248408
# 0   0.164570  0.031847  0.031847  0.031847  0.031847  0.031847  0.254777
#
#      r_at_50
# 22  0.987261
# 24  0.974522
# 5   0.993631
# 18  1.000000
# 4   0.974522
# 19  1.000000
# 12  1.000000
# 7   1.000000
# 13  1.000000
# 14  1.000000
# 8   1.000000
# 20  1.000000
# 23  0.968153
# 6   1.000000
# 1   1.000000
# 2   0.987261
# 21  1.000000
# 27  1.000000
# 26  1.000000
# 11  1.000000
# 17  1.000000
# 16  1.000000
# 10  1.000000
# 9   1.000000
# 15  1.000000
# 25  1.000000
# 3   1.000000
# 0   1.000000
#
# [28 rows x 23 columns]

# %%
output.loc[22,:]
# Out:
# model_type                                                   LR
# clf           LogisticRegression(C=0.1, class_weight=None, d...
# parameters                         {'C': 0.01, 'penalty': 'l2'}
# baseline        top_10_eviction_rate    0.082285
# dtype: float64
# auc-roc                                                0.955736
# f1_at_5                                                0.571429
# f1_at_10                                               0.691643
# a_at_5                                                 0.943396
# a_at_10                                                 0.94392
# p_at_1                                                        1
# p_at_2                                                 0.973684
# p_at_5                                                 0.757895
# p_at_10                                                0.631579
# p_at_20                                                0.377953
# p_at_30                                                0.262238
# p_at_50                                                0.162474
# r_at_1                                                 0.121019
# r_at_2                                                 0.235669
# r_at_5                                                 0.458599
# r_at_10                                                0.764331
# r_at_20                                                0.917197
# r_at_30                                                0.955414
# r_at_50                                                0.987261
# Name: 22, dtype: object
